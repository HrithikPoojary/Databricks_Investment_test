# %%
# %sql

--External Volume
CREATE EXTERNAL VOLUME ashlamba.bronze.bronze_volume
LOCATION 's3://....'

# %%
# %sql

--Managed Volume
CREATE VOLUME ashlamba.bronze.bronze_volume;

# %%
# %sql
select * from read_files('/Volumes/ashlamba/bronze/bronze_volume/sales/fact_sales.csv',
                         format => 'csv',
                         header => True);
