# %%
dbutils.help()

# %%
dbutils.help("fs")

# %%
dbutils.fs.ls('/Volumes/ashlamba/bronze/bronze_volume/sales/')

# %%
dbutils.fs.mkdirs("/Volumes/ashlamba/bronze/bronze_volume/customer")

# %%
dbutils.fs.cp('/Volumes/ashlamba/bronze/bronze_volume/sales/fact_sales.csv' , '/Volumes/ashlamba/bronze/bronze_volume/customer/')

# %%
dbutils.fs.cp('/Volumes/ashlamba/bronze/bronze_volume/sales/','/Volumes/ashlamba/bronze/bronze_volume/customer/' , True)  #True=Folder Reversive

# %%
dbutils.fs.rm('/Volumes/ashlamba/bronze/bronze_volume/customer/fact_sales.csv')

# %%
dbutils.fs.put('/Volumes/ashlamba/bronze/bronze_volume/customer/test.txt', 'Hello There')

# %%
dbutils.fs.put('/Volumes/ashlamba/bronze/bronze_volume/customer/test.py',"print('Hello World')",True)

# %%
all_items = dbutils.fs.ls('/Volumes/ashlamba/bronze/bronze_volume/customer/')

files = [i.name for i in all_items]

files

# %%
for i in files:
    dbutils.fs.rm(f'/Volumes/ashlamba/bronze/bronze_volume/customer/{i}')

# %%
dbutils.widgets.text('para1','')

# %%
para = dbutils.widgets.get('para1')
print(para)

# %%
dbutils.fs.rm('/Volumes/ashlamba/bronze/bronze_volume/customer/')

# %%
dbutils.fs.mkdirs('/Volumes/ashlamba/bronze/bronze_volume/customers')

# %%
dbutils.fs.mkdirs('/Volumes/ashlamba/bronze/bronze_volume/products/')

# %%
dbutils.fs.mkdirs('/Volumes/ashlamba/bronze/bronze_volume/stores/')
