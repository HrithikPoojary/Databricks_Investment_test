# %%
df = (
        spark.read.option("readChangeFeed" , True)
                .option("startingVersion" ,  5)
                .option("endingVersion" , 5)
                .table("ashlamba.default.employees")
)

df.display()
