-- %%
select * from product_enr
where category = :para_val_category ;


select identifier(:para_category) from product_enr;

select identifier(:para_cat) , identifier(:para_prod_id) from product_enr;
