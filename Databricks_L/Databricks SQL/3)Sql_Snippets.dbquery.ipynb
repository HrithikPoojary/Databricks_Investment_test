-- %%
--static
-- 3 dots -> view -> Query Snippets -> create snippet -> replace(name) -> query we want to use

select * from product_enr
where category = :para_category; 

--dynamic
--in snippet = ${1:replace_this}. -> 1 = which order to edit(not usefull)
select * from product_enr
where category = "Toys";
