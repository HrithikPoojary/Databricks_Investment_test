# %%
spark.read.table("ashlamba.silver.sales_enr").display()

# %%
# %sql
select * from ashlamba.dlt_schema.food_type1_trg;

# %%
# %sql
select * from ashlamba.dlt_schema.food_type2_trg;

# %%
# %sql
select * from ashlamba.dlt_schema.food_type1_trg;

# %%
# %sql
select * from ashlamba.dlt_schema.food_type2_trg;
