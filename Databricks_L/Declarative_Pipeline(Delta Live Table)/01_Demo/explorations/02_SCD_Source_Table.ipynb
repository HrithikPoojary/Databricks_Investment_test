# %%
# %sql
CREATE TABLE ashlamba.bronze.food_src
(
    product_id int,
    product_name string,
    process_date TIMESTAMP
);

# %%
# %sql
INSERT INTO ashlamba.bronze.food_src
values(1 , 'honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'bread',current_timestamp());

# %%
# %sql
select * from ashlamba.bronze.food_src;

# %%
# %sql
INSERT INTO ashlamba.bronze.food_src
values(1 , 'honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'bread',current_timestamp()),
(1 , 'honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'multigrainbread',current_timestamp()),
(4,'mint',current_timestamp());

# %%
# %sql
select * from ashlamba.bronze.food_src;
