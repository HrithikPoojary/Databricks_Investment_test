# %%
# %sql
select * from ashlamba.bronze.food_src;

# %%
# %sql
create table ashlamba.bronze.food_src_ctas as 
select * from ashlamba.bronze.food_src;

# %%
# %sql
select * from ashlamba.bronze.food_src_ctas;

# %%
# %sql
create or replace table ashlamba.bronze.food_src_deep_clone
deep clone ashlamba.bronze.food_src;

# %%
# %sql
describe history ashlamba.bronze.food_src_deep_clone;

# %%
# %sql
create or replace table ashlamba.bronze.food_src_shallow_clone
shallow clone ashlamba.bronze.food_src;

# %%
# %sql
select * from ashlamba.bronze.food_src_shallow_clone;
