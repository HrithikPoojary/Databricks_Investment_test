# %%
my_array = [
    {
        "parent_folder_name" : "Raw",
        "folder_name" : "customers"
    },
    {
        "parent_folder_name" : "Raw",
        "folder_name" : "products"
    },
    {
        "parent_folder_name" : "Raw",
        "folder_name" : "sales"
    },
    {
        "parent_folder_name" : "Raw",
        "folder_name" : "stores"
    }
]

# %%
dbutils.jobs.taskValues.set(key="myarray" , value = my_array)

# %%
length_array = len(my_array)
dbutils.jobs.taskValues.set(key="array_length",value = length_array)
