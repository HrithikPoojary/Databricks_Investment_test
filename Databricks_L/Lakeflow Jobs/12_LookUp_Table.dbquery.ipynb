-- %%
-- create or replace table lookup_table
-- (
--     parent_folder_name string,
--     folder_name string
-- );

-- insert into lookup_table
-- values('Raw','customers'),
-- ('Raw','products'),
-- ('Raw','sales'),
-- ('Raw','stores');

select * from lookup_table;
