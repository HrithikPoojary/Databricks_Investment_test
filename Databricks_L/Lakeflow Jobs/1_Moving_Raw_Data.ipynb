# %%
df = spark.read.format("csv")\
                .option("header","true")\
                .option("inferSchema" , "true")\
                .load("/Volumes/ashlamba/bronze/bronze_volume/stores/")

# %%
df.write.format("delta")\
        .mode("overwrite")\
        .save("/Volumes/ashlamba/bronze/job_volume/Raw/Stores/")
