# %%
dbutils.widgets.text("para1",'')

# %%
#job parameter

para1 = dbutils.widgets.get("para1")
para1

# %%
#Directly fetching the task value

var = dbutils.jobs.taskValues.get(taskKey='Lookup_Start_task',key='lookup_output')
var
