# %%
dbutils.widgets.text('sql_output','')

# %%
sql_output = dbutils.widgets.get("sql_output")
sql_output

# %%
from pyspark.sql.functions import *

# %%
list_sql_output = eval(sql_output)
list_sql_output

# %%
dbutils.jobs.taskValues.set(key = 'sql_output_arrays' , value = sql_output)
