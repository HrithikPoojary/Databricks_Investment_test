# %%
dbutils.widgets.text("single_row" , "")
dbutils.widgets.text("single_col" , '')

# %%
var_row = dbutils.widgets.get("single_row")
var_col = dbutils.widgets.get("single_col")
print(var_row)
print(var_col)
