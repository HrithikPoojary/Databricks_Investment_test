# %%
with open('/Workspace/Users/hrithikpoojary29@gmail.com/Databricks_Investment_test/Databricks_L/Silvel_Layer/demo_files.txt','r')as f:
    print(f.read())

# %%
with open('/Workspace/Users/hrithikpoojary29@gmail.com/Databricks_Investment_test/Databricks_L/Silvel_Layer/demo_python.py' , 'w') as f:
    f.write("my_secret=12345")

# %%
import demo_python

demo_python.my_secret

# %%
import pandas as pd 

df = pd.read_json('/Workspace/Users/hrithikpoojary29@gmail.com/Databricks_Investment_test/Databricks_L/Silvel_Layer/mapping.json')

df.head()

# %%
df_pyspark = spark.createDataFrame(df)
df_pyspark.display()
