# %%
# %sql
create or replace function ashlamba.bronze.scalar_fun_udf(p_id int)
returns int 
language sql 
return p_id*10

# %%
# %sql
select ashlamba.bronze.scalar_fun_udf(total_amount) from ashlamba.silver.sales_enr;
