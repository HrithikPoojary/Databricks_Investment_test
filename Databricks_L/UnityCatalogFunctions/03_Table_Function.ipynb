# %%
# %sql
create or replace function ashlamba.bronze.table_fun(p_id int)
returns table 
return (select * from ashlamba.silver.sales_enr where total_amount>p_id)

# %%
# %sql
select * from ashlamba.bronze.table_fun(1000);
