# %%
# %sql
CREATE OR REPLACE TABLE dev.spark_db.quantity(
    account_number string,
    asset_external_id string,
    available_quantity decimal(18,2),
    quantity_ver smallint,
    quantity_dml timestamp
)
using delta
LOCATION '';

# %%
# %sql
insert into dev.spark_db.quantity values ("97940-69402"	,"HDFCBANK",	100.00,	1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("06932-99420"	,"TCS",	100.00,	1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("126934-24574"	,"HDFCBANK"	,100.00	,1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("06932-99420",	"RELIANCE"	,100.00,1	,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("07942-19393"	,"RELIANCE",	100.00,1,	"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("907958-17375",	"AMZN"	,100.00	,1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("97940-69402"	,"AAPL",	100.00	,1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("468902-67386"	,"RELIANCE"	,100.00	,1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("468902-67386"	,"NVDA"	,100.00,1,	"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("12059-49504"	,"GOOGL",	100.00,	1,"2026-05-17T16:59:27.052+00:00");
insert into dev.spark_db.quantity values ("896995-28486"	,"GOOGL"	,100.00,	1,"2026-05-17T16:59:27.052+00:00");
