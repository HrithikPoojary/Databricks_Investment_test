# %%
# %sql
create or replace table dev.spark_db.transaction(
    transaction_id bigint generated always as identity(start with 10000 increment by 1),
    account_number string,
    asset_external_id string,
    order_type string,
    quantity decimal(18,2),
    asset_rate decimal(18,2),
    order_amt decimal(18,2),
    as_of_dt date,
    transaction_ver smallint,
    transaction_dml timestamp
)
using delta
location '';

# %%
# %sql
drop table dev.spark_db.transaction;
